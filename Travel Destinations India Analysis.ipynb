# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the dataset

travel_data = pd.read_csv(r"C:\Users\sujal patil\OneDrive\Desktop\PYTHON PROJECT\Top Indian Places to Visit.csv")

# %%
travel_data
# Out:
#      Unnamed: 0      Zone           State         City  \
# 0             0  Northern           Delhi        Delhi
# 1             1  Northern           Delhi        Delhi
# 2             2  Northern           Delhi        Delhi
# 3             3  Northern           Delhi        Delhi
# 4             4  Northern           Delhi        Delhi
# ..          ...       ...             ...          ...
# 320         320   Western         Gujarat  Gandhinagar
# 321         321   Central   Uttar Pradesh         Agra
# 322         322   Central  Madhya Pradesh       Bhopal
# 323         323  Northern       Rajasthan       Jaipur
# 324         324  Northern       Rajasthan       Jaipur
#
#                              Name          Type Establishment Year  \
# 0                      India Gate  War Memorial               1921
# 1                  Humayun's Tomb          Tomb               1572
# 2               Akshardham Temple        Temple               2005
# ...

# %%
# Display the first five rows of the dataframe.

travel_data.head()
# Out:
#    Unnamed: 0      Zone  State   City                  Name          Type  \
# 0           0  Northern  Delhi  Delhi            India Gate  War Memorial
# 1           1  Northern  Delhi  Delhi        Humayun's Tomb          Tomb
# 2           2  Northern  Delhi  Delhi     Akshardham Temple        Temple
# 3           3  Northern  Delhi  Delhi  Waste to Wonder Park    Theme Park
# 4           4  Northern  Delhi  Delhi         Jantar Mantar   Observatory
#
#   Establishment Year  time needed to visit in hrs  Google review rating  \
# 0               1921                          0.5                   4.6
# 1               1572                          2.0                   4.5
# 2               2005                          5.0                   4.6
# 3               2019                          2.0                   4.1
# 4               1724                          2.0                   4.2
#
#    Entrance Fee in INR Airport with 50km Radius Weekly Off   Significance  \
# ...

# %%
# Display the last five rows of the dataframe.

travel_data.tail()
# Out:
#      Unnamed: 0      Zone           State         City  \
# 320         320   Western         Gujarat  Gandhinagar
# 321         321   Central   Uttar Pradesh         Agra
# 322         322   Central  Madhya Pradesh       Bhopal
# 323         323  Northern       Rajasthan       Jaipur
# 324         324  Northern       Rajasthan       Jaipur
#
#                              Name    Type Establishment Year  \
# 320                    Akshardham  Temple               1992
# 321                     Agra Fort    Fort               1565
# 322  Madhya Pradesh Tribal Museum  Museum               2013
# 323                   City Palace  Palace               1727
# 324            Albert Hall Museum  Museum               1887
#
#      time needed to visit in hrs  Google review rating  Entrance Fee in INR  \
# 320                          3.0                   4.6                    0
# 321                          2.0                   4.5                   40
# ...

# %%
# Summary of the DataFrame structure.

travel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        325 non-null    int64
#  1   Zone                              325 non-null    object
#  2   State                             325 non-null    object
#  3   City                              325 non-null    object
#  4   Name                              325 non-null    object
#  5   Type                              325 non-null    object
#  6   Establishment Year                325 non-null    object
#  7   time needed to visit in hrs       325 non-null    float64
#  8   Google review rating              325 non-null    float64
#  9   Entrance Fee in INR               325 non-null    int64
#  10  Airport with 50km Radius          325 non-null    object
# ...

# %%
# Descriptive statistics of the DataFrame for numeric columns.

travel_data.describe()
# Out:
#        Unnamed: 0  time needed to visit in hrs  Google review rating  \
# count  325.000000                   325.000000            325.000000
# mean   162.000000                     1.807692              4.486154
# std     93.963645                     0.971398              0.274580
# min      0.000000                     0.500000              1.400000
# 25%     81.000000                     1.000000              4.400000
# 50%    162.000000                     1.500000              4.500000
# 75%    243.000000                     2.000000              4.600000
# max    324.000000                     7.000000              4.900000
#
#        Entrance Fee in INR  Number of google review in lakhs
# count           325.000000                        325.000000
# mean            115.809231                          0.408438
# std             530.859785                          0.646668
# min               0.000000                          0.010000
# ...

# %%
#  Dimensions of the DataFrame (rows, columns).

travel_data.shape
# Out:
# (325, 16)

# %%
# Total number of elements (cells) in the DataFrame.

travel_data.size
# Out:
# 5200

# %%
# Drop unnecessary Columns

travel_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
travel_data.head()
# Out:
#        Zone  State   City                  Name          Type  \
# 0  Northern  Delhi  Delhi            India Gate  War Memorial
# 1  Northern  Delhi  Delhi        Humayun's Tomb          Tomb
# 2  Northern  Delhi  Delhi     Akshardham Temple        Temple
# 3  Northern  Delhi  Delhi  Waste to Wonder Park    Theme Park
# 4  Northern  Delhi  Delhi         Jantar Mantar   Observatory
#
#   Establishment Year  time needed to visit in hrs  Google review rating  \
# 0               1921                          0.5                   4.6
# 1               1572                          2.0                   4.5
# 2               2005                          5.0                   4.6
# 3               2019                          2.0                   4.1
# 4               1724                          2.0                   4.2
#
#    Entrance Fee in INR Airport with 50km Radius Weekly Off   Significance  \
# 0                    0                      Yes        NaN     Historical
# ...

# %%
travel_data.isnull().sum()
# Out:
# Zone                                  0
# State                                 0
# City                                  0
# Name                                  0
# Type                                  0
# Establishment Year                    0
# time needed to visit in hrs           0
# Google review rating                  0
# Entrance Fee in INR                   0
# Airport with 50km Radius              0
# Weekly Off                          293
# Significance                          0
# DSLR Allowed                          0
# Number of google review in lakhs      0
# Best Time to visit                    0
# dtype: int64

# %%
travel_data['Weekly Off'].value_counts()
# Out:
# Weekly Off
# Monday     23
# Friday      5
# Sunday      2
# Yes         1
# Tuesday     1
# Name: count, dtype: int64

# %%
travel_data['Weekly Off'].fillna('ALL day open', inplace=True)

# %%
travel_data.head()
# Out:
#        Zone  State   City                  Name          Type  \
# 0  Northern  Delhi  Delhi            India Gate  War Memorial
# 1  Northern  Delhi  Delhi        Humayun's Tomb          Tomb
# 2  Northern  Delhi  Delhi     Akshardham Temple        Temple
# 3  Northern  Delhi  Delhi  Waste to Wonder Park    Theme Park
# 4  Northern  Delhi  Delhi         Jantar Mantar   Observatory
#
#   Establishment Year  time needed to visit in hrs  Google review rating  \
# 0               1921                          0.5                   4.6
# 1               1572                          2.0                   4.5
# 2               2005                          5.0                   4.6
# 3               2019                          2.0                   4.1
# 4               1724                          2.0                   4.2
#
#    Entrance Fee in INR Airport with 50km Radius    Weekly Off   Significance  \
# 0                    0                      Yes  ALL day open     Historical
# ...

# %%
travel_data["State"] = travel_data["State"].replace("Maharastra", "Maharashtra")

# %%
# Rename confusing column headers.

travel_data.rename(columns={
    'time needed to visit in hrs': 'Time Needed (hrs)',
    'Google review rating': 'Google Rating',
    'Entrance Fee in INR': 'Entrance Fee (INR)',
    'Airport with 50km Radius': 'Nearby Airport',
    'Number of google review in lakhs': 'Google Reviews (Lakhs)',
    'Best Time to visit': 'Best Time'
}, inplace=True)

travel_data.head()
# Out:
#        Zone  State   City                  Name          Type  \
# 0  Northern  Delhi  Delhi            India Gate  War Memorial
# 1  Northern  Delhi  Delhi        Humayun's Tomb          Tomb
# 2  Northern  Delhi  Delhi     Akshardham Temple        Temple
# 3  Northern  Delhi  Delhi  Waste to Wonder Park    Theme Park
# 4  Northern  Delhi  Delhi         Jantar Mantar   Observatory
#
#   Establishment Year  Time Needed (hrs)  Google Rating  Entrance Fee (INR)  \
# 0               1921                0.5            4.6                   0
# 1               1572                2.0            4.5                  30
# 2               2005                5.0            4.6                  60
# 3               2019                2.0            4.1                  50
# 4               1724                2.0            4.2                  15
#
#   Nearby Airport    Weekly Off   Significance DSLR Allowed  \
# 0            Yes  ALL day open     Historical          Yes
# ...

# %%
# Replace 'Unknown' or missing values in 'Establishment Year' with NaN and convert to numeric.

travel_data['Establishment Year'].replace('Unknown', pd.NA, inplace=True)
travel_data['Establishment Year'] = pd.to_numeric(travel_data['Establishment Year'], errors='coerce')

travel_data.head(20)
# 16th value showed 'unknown' which is changed to 'NaN'.
# Out:
#         Zone        State    City  \
# 0   Northern        Delhi   Delhi
# 1   Northern        Delhi   Delhi
# 2   Northern        Delhi   Delhi
# 3   Northern        Delhi   Delhi
# 4   Northern        Delhi   Delhi
# 5   Northern        Delhi   Delhi
# 6   Northern        Delhi   Delhi
# 7   Northern        Delhi   Delhi
# 8   Northern        Delhi   Delhi
# 9   Northern        Delhi   Delhi
# 10  Northern        Delhi   Delhi
# 11  Northern        Delhi   Delhi
# 12  Northern        Delhi   Delhi
# 13  Northern        Delhi   Delhi
# 14  Northern        Delhi   Delhi
# 15  Northern        Delhi   Delhi
# 16   Western  Maharashtra  Mumbai
# 17   Western  Maharashtra  Mumbai
# 18   Western  Maharashtra  Mumbai
# 19   Western  Maharashtra  Mumbai
#
#                                               Name           Type  \
# 0                                       India Gate   War Memorial
# 1                                   Humayun's Tomb           Tomb
# ...

# %%
# All places in Gujarat

travel_data[travel_data['State'] == 'Gujarat']
# Out:
#         Zone    State           City                  Name  \
# 66   Western  Gujarat      Ahmedabad      Sabarmati Ashram
# 67   Western  Gujarat         Dwarka    Dwarkadhish Temple
# 68   Western  Gujarat       Junagadh     Gir National Park
# 69   Western  Gujarat           Bhuj          White Desert
# 70   Western  Gujarat       Vadodara    Laxmi Vilas Palace
# 71   Western  Gujarat        Somnath        Somnath Temple
# 72   Western  Gujarat  Rann of Kutch            Rann Utsav
# 73   Western  Gujarat        Kevadia       Statue of Unity
# 74   Western  Gujarat    Gandhinagar           Dandi Kutir
# 75   Western  Gujarat      Ahmedabad  Sabarmati Riverfront
# 76   Western  Gujarat      Ahmedabad           Manek Chowk
# 77   Western  Gujarat      Ahmedabad         Kankaria Lake
# 78   Western  Gujarat      Ahmedabad          Science City
# 320  Western  Gujarat    Gandhinagar            Akshardham
#
#                           Type  Establishment Year  Time Needed (hrs)  \
# ...

# %%
# All places in Western Zone

travel_data[travel_data['Zone'] == 'Western']
# Out:
#         Zone          State           City  \
# 16   Western    Maharashtra         Mumbai
# 17   Western    Maharashtra         Mumbai
# 18   Western    Maharashtra         Mumbai
# 19   Western    Maharashtra         Mumbai
# 20   Western    Maharashtra         Mumbai
# 21   Western    Maharashtra         Mumbai
# 22   Western    Maharashtra         Mumbai
# 23   Western    Maharashtra         Mumbai
# 24   Western    Maharashtra         Mumbai
# 25   Western    Maharashtra         Mumbai
# 26   Western    Maharashtra       Lonavala
# 66   Western        Gujarat      Ahmedabad
# 67   Western        Gujarat         Dwarka
# 68   Western        Gujarat       Junagadh
# 69   Western        Gujarat           Bhuj
# 70   Western        Gujarat       Vadodara
# 71   Western        Gujarat        Somnath
# 72   Western        Gujarat  Rann of Kutch
# 73   Western        Gujarat        Kevadia
# 74   Western        Gujarat    Gandhinagar
# 75   Western        Gujarat      Ahmedabad
# ...

# %%
# Highly-rated & popular places.

travel_data[(travel_data['Google Rating'] > 4.5) & (travel_data['Google Reviews (Lakhs)'] > 4)]
# Out:
#         Zone          State           City                         Name  \
# 315  Central  Uttar Pradesh  Greater Noida  Buddh International Circuit
#
#            Type  Establishment Year  Time Needed (hrs)  Google Rating  \
# 315  Race Track              2011.0                2.0            4.6
#
#      Entrance Fee (INR) Nearby Airport Weekly Off Significance DSLR Allowed  \
# 315                1500            Yes     Sunday       Sports          Yes
#
#      Google Reviews (Lakhs) Best Time
# 315                     7.4       All

# %%
# Free or very low-cost places (under ₹50)

travel_data[travel_data['Entrance Fee (INR)'] <= 50].sample(n = 5)
# Out:
#          Zone             State           City                           Name  \
# 160  Northern  Himachal Pradesh          Mandi                   Prashar Lake
# 260  Southern    Andhra Pradesh  Visakhapatnam               Submarine Museum
# 74    Western           Gujarat    Gandhinagar                    Dandi Kutir
# 155  Northern  Himachal Pradesh          Kullu  Great Himalayan National Park
# 71    Western           Gujarat        Somnath                 Somnath Temple
#
#               Type  Establishment Year  Time Needed (hrs)  Google Rating  \
# 160           Lake              1400.0                1.5            4.6
# 260         Museum                22.0                1.0            4.6
# 74          Museum              2013.0                1.5            4.5
# 155  National Park              1984.0                3.0            4.5
# 71          Temple              1951.0                2.0            4.8
#
# ...

# %%
# Places best to visit in Evening.

travel_data[travel_data['Best Time'].str.contains('Evening', na=False)].head()
# Out:
#         Zone        State    City                  Name          Type  \
# 0   Northern        Delhi   Delhi            India Gate  War Memorial
# 3   Northern        Delhi   Delhi  Waste to Wonder Park    Theme Park
# 6   Northern        Delhi   Delhi          Lotus Temple        Temple
# 16   Western  Maharashtra  Mumbai          Marine Drive     Promenade
# 23   Western  Maharashtra  Mumbai       Chowpatty Beach         Beach
#
#     Establishment Year  Time Needed (hrs)  Google Rating  Entrance Fee (INR)  \
# 0               1921.0                0.5            4.6                   0
# 3               2019.0                2.0            4.1                  50
# 6               1986.0                1.0            4.5                   0
# 16                 NaN                2.0            4.5                   0
# 23                 NaN                2.0            4.3                   0
#
#    Nearby Airport    Weekly Off   Significance DSLR Allowed  \
# ...

# %%
travel_data["Zone"].value_counts()
# Out:
# Zone
# Southern         98
# Northern         89
# Eastern          45
# Western          40
# Central          39
# North Eastern    14
# Name: count, dtype: int64

# %%
# Distribution of Landmarks by Zone

plt.figure(figsize=(10, 6), dpi=200)
sns.countplot(x='Zone', data=travel_data, order = travel_data['Zone'].value_counts().index)
plt.title('Distribution of Landmarks by Zone')
plt.xlabel('Zone')
plt.ylabel('Number of Landmarks')
plt.show()

# %%
travel_data["State"].value_counts()
# Out:
# State
# Maharashtra                    24
# Uttar Pradesh                  23
# West Bengal                    20
# Karnataka                      19
# Delhi                          19
# Himachal Pradesh               18
# Andhra Pradesh                 18
# Kerala                         16
# Madhya Pradesh                 15
# Rajasthan                      15
# Goa                            14
# Uttarakhand                    14
# Gujarat                        14
# Tamil Nadu                     13
# Odisha                         12
# Telangana                      11
# Ladakh                         10
# Assam                           8
# Sikkim                          7
# Jammu and Kashmir               6
# Punjab                          4
# Andaman and Nicobar Islands     4
# Bihar                           4
# Tripura                         3
# Haryana                         3
# Puducherry                      3
# Jharkhand                       2
# ...

# %%
# Distribution of Landmarks by State (Top 10)

plt.figure(figsize=(10, 6), dpi=200)
state_counts = travel_data['State'].value_counts()
sns.barplot(x=state_counts, y=state_counts.index, color = "grey")
plt.title('States by Number of Landmarks')
plt.xlabel('Number of Landmarks')
plt.ylabel('State')
plt.show()

# %%
# Types of Landmarks
plt.figure(figsize=(12, 8), dpi=200)
type_counts = travel_data['Type'].value_counts().head(20)
sns.barplot(x=type_counts, y=type_counts.index, color = "r")
plt.title('Top 20 Types of Landmarks')
plt.xlabel('Number of Landmarks')
plt.ylabel('Type')
plt.show()

# %%
travel_data["Google Rating"].value_counts()
# Out:
# Google Rating
# 4.5    70
# 4.6    64
# 4.4    55
# 4.7    48
# 4.8    26
# 4.3    17
# 4.1    15
# 4.2    15
# 3.9     6
# 4.9     3
# 3.8     3
# 1.4     1
# 4.0     1
# 3.7     1
# Name: count, dtype: int64

# %%
# Review Ratings and Entrance Fees
plt.figure(figsize=(10, 6),dpi=200)
sns.scatterplot(data=travel_data, x='Google Rating', y='Entrance Fee (INR)', color = "g")
plt.title('Review Ratings vs. Entrance Fees')
plt.xlabel('Google Rating')
plt.ylabel('Entrance Fee (INR)')
plt.show()

# %%
# Time Needed to Visit
plt.figure(figsize=(10, 6), dpi=200)
sns.histplot(travel_data['Time Needed (hrs)'], bins=20, kde=True, color = "y")
plt.title('Distribution of Time Needed to Visit')
plt.xlabel('Time Needed to Visit (hrs)')
plt.ylabel('Number of Landmarks')
plt.show()

# %%
# Filtering top-rated and popular spots(4.5+ rating, 2L+ reviews)
filtered_df = travel_data[(travel_data['Google Rating'] >= 4.5) & (travel_data['Google Reviews (Lakhs)'] >= 2)]

# %%
filtered_df
# Out:
#          Zone          State           City                         Name  \
# 0    Northern          Delhi          Delhi                   India Gate
# 17    Western    Maharashtra         Mumbai             Gateway of India
# 32   Southern      Telangana      Hyderabad                    Charminar
# 101  Southern         Kerala        Wayanad   Wayanad Wildlife Sanctuary
# 111  Southern      Karnataka         Mysore                Mysore Palace
# 181   Central  Uttar Pradesh           Agra                    Taj Mahal
# 306  Northern    Uttarakhand      Kedarnath                    Kedarnath
# 315   Central  Uttar Pradesh  Greater Noida  Buddh International Circuit
#
#                    Type  Establishment Year  Time Needed (hrs)  Google Rating  \
# 0          War Memorial              1921.0                0.5            4.6
# 17             Monument              1924.0                1.0            4.6
# ...

# %%
#Top-rated and popular spots(4.5+ rating, 2L+ reviews) ensure a safe, memorable visit.
plt.figure(figsize=(10, 6))
sns.barplot(data=filtered_df, y='Name', x='Google Rating', palette='viridis')
plt.title('Top Rated Places with More Than 2 lakh Google Reviews')
plt.xlabel('Google Rating')
plt.ylabel('Place Name')
plt.show()

# %%
top10_types = travel_data['Type'].value_counts().head(10).index

# Filter the dataframe to only include these top 20 types
filtered_top10_df = travel_data[travel_data['Type'].isin(top10_types)]

# %%
plt.figure(figsize=(14, 8), dpi=200)
sns.countplot(data=filtered_top10_df,y='Type',hue='Zone',
              order=top10_types,
              palette='Set1')
plt.title('Type of Attractions by Region', fontsize=16)
plt.xlabel('Number of Places', fontsize=14)
plt.ylabel('Type of Attraction', fontsize=14)
plt.legend(title='Region')
plt.show()
